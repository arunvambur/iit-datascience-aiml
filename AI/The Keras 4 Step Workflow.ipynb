# %%
# !pip install tensorflow
# !pip install keras

# %%
# Define the training data
import numpy as np

X_train = np.random.random((5000, 33))
y_train = np.random.random((5000,1))

# %%
X_train[0]
# Out:
# array([0.86017056, 0.81724117, 0.65573465, 0.4828349 , 0.86826407,
#        0.08076196, 0.99472117, 0.59966156, 0.5647935 , 0.82875897,
#        0.10952329, 0.52733662, 0.54121163, 0.2815503 , 0.62930237,
#        0.77475316, 0.1074531 , 0.76661112, 0.90824126, 0.31443435,
#        0.98608357, 0.87385966, 0.01044194, 0.23998386, 0.73043873,
#        0.05923643, 0.97065996, 0.38097858, 0.52149103, 0.96576654,
#        0.00118953, 0.02635546, 0.41092187])

# %%
y_train
# Out:
# array([[0.54437665],
#        [0.93718008],
#        [0.4733511 ],
#        ...,
#        [0.32527945],
#        [0.70308889],
#        [0.47463455]])

# %%
# Define the neural network model
# sequential/functional
from keras import models
# dense, dropout
from keras import layers

INPUT_DIM = X_train.shape[1]
INPUT_DIM
# Out:
# 33

# %%
# define structure of the model
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_dim=INPUT_DIM))
model.add(layers.Dense(16, activation='sigmoid'))
model.add(layers.Dense(16, activation='tanh'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                544
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 16)                272
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1377 (5.38 KB)
# Trainable params: 1377 (5.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Configure the learning process
from keras import optimizers
from keras import metrics

model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train,
          batch_size=100,
          epochs=50,
          verbose =1)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.0000e+00
# Epoch 2/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.0000e+00
# Epoch 3/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.0000e+00
# Epoch 4/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0791 - accuracy: 0.0000e+00
# Epoch 5/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.0000e+00
# Epoch 6/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.0000e+00
# Epoch 7/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.0000e+00
# Epoch 8/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.0000e+00
# Epoch 9/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.0000e+00
# Epoch 10/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0785 - accuracy: 0.0000e+00
# Epoch 11/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.0000e+00
# Epoch 12/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.0000e+00
# Epoch 13/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.0000e+00
# Epoch 14/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.0000e+00
# Epoch 15/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.0000e+00
# Epoch 16/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.0000e+00
# Epoch 17/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.0000e+00
# Epoch 18/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.0000e+00
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0781 - accuracy: 0.0000e+00
# Epoch 20/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0779 - accuracy: 0.0000e+00
# Epoch 21/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0782 - accuracy: 0.0000e+00
# Epoch 22/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0779 - accuracy: 0.0000e+00
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0777 - accuracy: 0.0000e+00
# Epoch 24/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.0000e+00
# Epoch 25/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.0000e+00
# Epoch 26/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.0000e+00
# Epoch 27/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.0000e+00
# Epoch 28/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.0000e+00
# Epoch 29/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.0000e+00
# Epoch 30/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.0000e+00
# Epoch 31/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.0000e+00
# Epoch 32/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.0000e+00
# Epoch 33/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.0000e+00
# Epoch 34/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.0000e+00
# Epoch 35/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.0000e+00
# Epoch 36/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.0000e+00
# Epoch 37/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.0000e+00
# Epoch 38/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.0000e+00
# Epoch 39/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.0000e+00
# Epoch 40/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.0000e+00
# Epoch 41/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.0000e+00
# Epoch 42/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.0000e+00
# Epoch 43/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.0000e+00
# Epoch 44/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.0000e+00
# Epoch 45/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.0000e+00
# Epoch 46/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0765 - accuracy: 0.0000e+00
# Epoch 47/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0768 - accuracy: 0.0000e+00
# Epoch 48/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.0000e+00
# Epoch 49/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0765 - accuracy: 0.0000e+00
# Epoch 50/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.0000e+00

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                544
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 16)                272
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1377 (5.38 KB)
# Trainable params: 1377 (5.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

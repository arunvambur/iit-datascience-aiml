# %%
import os
import numpy as np
import pandas as pd

# %%
df_iris = pd.read_csv('Iris.csv')
df_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.subplots(figsize=(10, 5))
sns.boxplot(x=df_iris['Species'], y=df_iris['SepalLengthCm'])
plt.show()

# %%
plt.subplots(figsize=(10, 5))
sns.boxplot(x=df_iris['Species'], y=df_iris['SepalWidthCm'])
plt.show()

# %%
plt.subplots(figsize=(10, 5))
sns.boxplot(x=df_iris['Species'], y=df_iris['PetalLengthCm'])
plt.show()

# %%
df_iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sel_cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
df_iris_data = df_iris[sel_cols]
df_iris_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
X = df_iris[sel_cols]

# %%
y = df_iris['Species']
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
X_std = StandardScaler().fit_transform(X)

# %%
X.head(2)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2

# %%
X_std
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
X.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### Covariance Matrix

# %%
cov_mat = np.cov(X_std, rowvar=False)
cov_mat
# Out:
# array([[ 1.00671141, -0.11010327,  0.87760486,  0.82344326],
#        [-0.11010327,  1.00671141, -0.42333835, -0.358937  ],
#        [ 0.87760486, -0.42333835,  1.00671141,  0.96921855],
#        [ 0.82344326, -0.358937  ,  0.96921855,  1.00671141]])

# %%
cov_mat.shape
# Out:
# (4, 4)

# %% [markdown]
# ### Compute Eigen Values and Eigen Vectors

# %%
print('Covariance matrix \n')

eigen_values, eigen_vectors = np.linalg.eig(cov_mat)
print('Eigen values:\n', eigen_values)
print('Eigen vectors:\n', eigen_vectors)
# Out:
# Covariance matrix
#
# Eigen values:
#  [2.93035378 0.92740362 0.14834223 0.02074601]
# Eigen vectors:
#  [[ 0.52237162 -0.37231836 -0.72101681  0.26199559]
#  [-0.26335492 -0.92555649  0.24203288 -0.12413481]
#  [ 0.58125401 -0.02109478  0.14089226 -0.80115427]
#  [ 0.56561105 -0.06541577  0.6338014   0.52354627]]

# %% [markdown]
# ### selecting the 'K' Eigen values/Principal Components

# %%
tot = sum(eigen_values) #all of it
tot
# Out:
# 4.02684563758389

# %%
exp_var = [(i/tot)*100 for i in sorted(eigen_values, reverse=True)]
print('Variance Explained:', exp_var)
# Out:
# Variance Explained: [72.77045209380131, 23.030523267680664, 3.6838319576273926, 0.515192680890629]

# %%
eigen_values/tot*100
# Out:
# array([72.77045209, 23.03052327,  3.68383196,  0.51519268])

# %%
73 + 23
# Out:
# 96

# %% [markdown]
# #### Explained variance shows the contribution of each eigen value in explaining the variance within data. Let us say if `K=2` : two eigen values can explain 96% of variance then we can go with 2PCs

# %%
cum_exp_var = np.cumsum(exp_var)

# %%
print('Cumulative variance explained', cum_exp_var)
# Out:
# Cumulative variance explained [ 72.77045209  95.80097536  99.48480732 100.        ]

# %% [markdown]
# ### Projection Matrix `W` from the selected `K` eigen vectors

# %%
eigen_vectors
# Out:
# array([[ 0.52237162, -0.37231836, -0.72101681,  0.26199559],
#        [-0.26335492, -0.92555649,  0.24203288, -0.12413481],
#        [ 0.58125401, -0.02109478,  0.14089226, -0.80115427],
#        [ 0.56561105, -0.06541577,  0.6338014 ,  0.52354627]])

# %% [markdown]
# ### Make a list of (eigen values, eigen vectors)

# %%
eig_pairs = [(np.abs(eigen_values[i]), eigen_vectors[:,i]) for i in range(len(eigen_values))]
eig_pairs
# Out:
# [(2.930353775589313,
#   array([ 0.52237162, -0.26335492,  0.58125401,  0.56561105])),
#  (0.9274036215173417,
#   array([-0.37231836, -0.92555649, -0.02109478, -0.06541577])),
#  (0.1483422264816399,
#   array([-0.72101681,  0.24203288,  0.14089226,  0.6338014 ])),
#  (0.020746013995595784,
#   array([ 0.26199559, -0.12413481, -0.80115427,  0.52354627]))]

# %% [markdown]
# ### Select the first two

# %%
eig_pairs[0][1]
# Out:
# array([ 0.52237162, -0.26335492,  0.58125401,  0.56561105])

# %%
eig_pairs[1][1]
# Out:
# array([-0.37231836, -0.92555649, -0.02109478, -0.06541577])

# %%
matrix_w = np.hstack((eig_pairs[0][1].reshape(4, 1), eig_pairs[1][1].reshape(4, 1)))
matrix_w
# Out:
# array([[ 0.52237162, -0.37231836],
#        [-0.26335492, -0.92555649],
#        [ 0.58125401, -0.02109478],
#        [ 0.56561105, -0.06541577]])

# %%
Y = X_std.dot(matrix_w)

# %%
Y.shape
# Out:
# (150, 2)

# %%
pd_dataframe = pd.DataFrame(Y, columns=['PC1', 'PC2'])
pd_dataframe
# Out:
#           PC1       PC2
# 0   -2.264542 -0.505704
# 1   -2.086426  0.655405
# 2   -2.367950  0.318477
# 3   -2.304197  0.575368
# 4   -2.388777 -0.674767
# ..        ...       ...
# 145  1.870522 -0.382822
# 146  1.558492  0.905314
# 147  1.520845 -0.266795
# 148  1.376391 -1.016362
# 149  0.959299  0.022284
#
# [150 rows x 2 columns]

# %%
from sklearn.decomposition import PCA
pca_iris = PCA()
pca_iris.fit(X_std)
# Out:
# PCA()

# %%
loadings = pca_iris.components_
loadings
# Out:
# array([[ 0.52237162, -0.26335492,  0.58125401,  0.56561105],
#        [ 0.37231836,  0.92555649,  0.02109478,  0.06541577],
#        [-0.72101681,  0.24203288,  0.14089226,  0.6338014 ],
#        [-0.26199559,  0.12413481,  0.80115427, -0.52354627]])

# %%
loadings_df = pd.DataFrame(loadings, columns=X.columns)
loadings_df
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       0.522372     -0.263355       0.581254      0.565611
# 1       0.372318      0.925556       0.021095      0.065416
# 2      -0.721017      0.242033       0.140892      0.633801
# 3      -0.261996      0.124135       0.801154     -0.523546
